# %% [markdown]
# # Vacation Experience

# %% [markdown]
# This is notebook purpose is to introduce someone holidays preference. It will contain a picture and a youtube link of the holidays experience.

# %% [markdown]
# ---------------------------------------

# %% [markdown]
# <a name="x1"></a>
# ## *INPUT NAME*
# Input the name of the person that will describe the trip of your choice.

# %%
x = input("Name: ")
# Out:
# Name: Thiago

# %% [markdown]
# <a name="x2"></a>
# ## *PHOTO OF THE PERSON*

# %% [markdown]
# ![WhatsApp%20Image%202021-12-25%20at%2017.35.11.jpeg](attachment:WhatsApp%20Image%202021-12-25%20at%2017.35.11.jpeg)

# %% [markdown]
# <a name="x3"></a>
# ## *INPUT HOLIDAY INFORMATION*

# %%
y = input("Where do you wanna go? ")
w = input("When do you wanna go? ")
# Out:
# Where do you wanna go? Andorra
# When do you wanna go? Winter

# %% [markdown]
# <a name="x4"></a>
# ## *PHOTO OF THE PLACE*

# %% [markdown]
# ![andorra.jpg](attachment:andorra.jpg)

# %% [markdown]
# <a name="x5"></a>
# ## *INPUT HOLIDAY DETAILS*

# %%
print("Input 3 details from",y, "that comprove your choice:")
z = input("1.")
d = input("2.")
k = input("3.")
# Out:
# Input 3 details from Andorra that comprove your choice:
# 1.Practice Ski
# 2.Beautifull landscape
# 3.Near Barcelona

# %% [markdown]
# <a name="x6"></a>
# ## *VIDEO*

# %%
# import IPython.display.YouTubeVideo class.
from IPython.display import YouTubeVideo
# create an instance of YouTubeVideo class with provided youtube video id.
youtube_video = YouTubeVideo('x1sxbTYN2qo')
# display youtube video
display(youtube_video)

# %% [markdown]
# https://www.youtube.com/watch?v=VUXZrxPgyKA
