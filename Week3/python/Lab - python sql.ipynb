# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Create-a-connection-between-Python-and-the-Sakila-database." data-toc-modified-id="Create-a-connection-between-Python-and-the-Sakila-database.-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Create a connection between Python and the Sakila database.</a></span></li><li><span><a href="#Create-Python-function-named-rentals_may-to-connect-to-the-Sakila-database-and-return-dataframe-storing-the-data-from-rental-table-with-information-for-May-2005." data-toc-modified-id="Create-Python-function-named-rentals_may-to-connect-to-the-Sakila-database-and-return-dataframe-storing-the-data-from-rental-table-with-information-for-May-2005.-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Create Python function named rentals_may to connect to the Sakila database and return dataframe storing the data from rental table with information for May 2005.</a></span></li><li><span><a href="#Create-Python-function-named-rentals_june-to-connect-to-the-Sakila-database-and-return-dataframe-storing-the-data-from-rental-table-with-information-for-June-2005." data-toc-modified-id="Create-Python-function-named-rentals_june-to-connect-to-the-Sakila-database-and-return-dataframe-storing-the-data-from-rental-table-with-information-for-June-2005.-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Create Python function named rentals_june to connect to the Sakila database and return dataframe storing the data from rental table with information for June 2005.</a></span></li><li><span><a href="#Create-a-Python-function-to-get-the-number-of-rentals-for-each-customer-in-May-given-the-dataframe-provided-by-the-function-rentals_may.-Hint:-Consider-making-use-of-pandas-groupby()-and-pandas-agg()" data-toc-modified-id="Create-a-Python-function-to-get-the-number-of-rentals-for-each-customer-in-May-given-the-dataframe-provided-by-the-function-rentals_may.-Hint:-Consider-making-use-of-pandas-groupby()-and-pandas-agg()-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Create a Python function to get the number of rentals for each customer in May given the dataframe provided by the function rentals_may. Hint: Consider making use of pandas groupby() and pandas agg()</a></span></li><li><span><a href="#Create-a-Python-function-to-get-the-number-of-rentals-for-each-customer-in-June-given-the-dataframe-provided-by-the-function-rentals_june." data-toc-modified-id="Create-a-Python-function-to-get-the-number-of-rentals-for-each-customer-in-June-given-the-dataframe-provided-by-the-function-rentals_june.-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Create a Python function to get the number of rentals for each customer in June given the dataframe provided by the function rentals_june.</a></span></li><li><span><a href="#Write-a-Python-function-named-check_rentals-that-given:" data-toc-modified-id="Write-a-Python-function-named-check_rentals-that-given:-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Write a Python function named check_rentals that given:</a></span></li><li><span><a href="#Create-a-Python-function-that-given-the-dataframe-returned-by-the-previous-function,-returns-another-dataframe-with-the-customer_id-of-customers-who-rented-movies-in-may-but-didn't-rent-any-movie-in-June." data-toc-modified-id="Create-a-Python-function-that-given-the-dataframe-returned-by-the-previous-function,-returns-another-dataframe-with-the-customer_id-of-customers-who-rented-movies-in-may-but-didn't-rent-any-movie-in-June.-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Create a Python function that given the dataframe returned by the previous function, returns another dataframe with the customer_id of customers who rented movies in may but didn't rent any movie in June.</a></span></li></ul></div>

# %%
import sys
print(sys.setrecursionlimit(2000))
# Out:
# None

# %% [markdown]
# # Create a connection between Python and the Sakila database.
# * need a library or package to connect these two
# * we will use sqlalchemy and pymysql

# %%
import pymysql
import sqlalchemy
from sqlalchemy import create_engine 
import pandas as pd
import getpass

# %%
mysql_pw=getpass.getpass()
# Out:
# ········

# %%
connection_string='mysql+pymysql://root:'+ mysql_pw +'@localhost:3306/sakila'
engine=create_engine(connection_string)

# %% [markdown]
# # Create Python function named rentals_may to connect to the Sakila database and return dataframe storing the data from rental table with information for May 2005.

# %%
def rentals_may (engine):
    query= ('''(select * from rental where rental_date between '2005-05-01 00:00:00' and '2005-06-01 00:00:00')''')
    data=pd.read_sql_query(query,engine)
    return data

# %%
df_may= rentals_may(engine)
df_may
# Out:
#       rental_id         rental_date  inventory_id  customer_id  \
# 0             1 2005-05-24 22:53:30           367          130
# 1             2 2005-05-24 22:54:33          1525          459
# 2             3 2005-05-24 23:03:39          1711          408
# 3             4 2005-05-24 23:04:41          2452          333
# 4             5 2005-05-24 23:05:21          2079          222
# ...         ...                 ...           ...          ...
# 1151       1153 2005-05-31 21:36:44          2725          506
# 1152       1154 2005-05-31 21:42:09          2732           59
# 1153       1155 2005-05-31 22:17:11          2048          251
# 1154       1156 2005-05-31 22:37:34           460          106
# 1155       1157 2005-05-31 22:47:45          1449           61
#
#              return_date  staff_id         last_update
# 0    2005-05-26 22:04:30         1 2006-02-15 21:30:53
# 1    2005-05-28 19:40:33         1 2006-02-15 21:30:53
# ...

# %% [markdown]
# # Create Python function named rentals_june to connect to the Sakila database and return dataframe storing the data from rental table with information for June 2005.

# %%
def rentals_june (engine):
    query= ('''(select * from rental where rental_date between '2005-06-01 00:00:00' and '2005-07-01 00:00:00')''')
    data=pd.read_sql_query(query,engine)
    return data

# %%
df_june = rentals_june(engine)
df_june
# Out:
#       rental_id         rental_date  inventory_id  customer_id  \
# 0          1158 2005-06-14 22:53:33          1632          416
# 1          1159 2005-06-14 22:55:13          4395          516
# 2          1160 2005-06-14 23:00:34          2795          239
# 3          1161 2005-06-14 23:07:08          1690          285
# 4          1162 2005-06-14 23:09:38           987          310
# ...         ...                 ...           ...          ...
# 2306       3465 2005-06-21 22:10:01          1488          510
# 2307       3466 2005-06-21 22:13:33           371          226
# 2308       3467 2005-06-21 22:19:25           729          543
# 2309       3468 2005-06-21 22:43:45          2899          100
# 2310       3469 2005-06-21 22:48:59          4087          181
#
#              return_date  staff_id         last_update
# 0    2005-06-18 21:37:33         2 2006-02-15 21:30:53
# 1    2005-06-17 02:11:13         1 2006-02-15 21:30:53
# ...

# %% [markdown]
# # Create a Python function to get the number of rentals for each customer in May given the dataframe provided by the function rentals_may. Hint: Consider making use of pandas groupby() and pandas agg()

# %%
def customer_may(df):
    x = df.groupby("customer_id", as_index=False).agg('count')
    x['num_rentals']= x['rental_id']
    return x[['customer_id', 'num_rentals']]
df_may = customer_may(rentals_may(engine))
df_may
# Out:
#      customer_id  num_rentals
# 0              1            2
# 1              2            1
# 2              3            2
# 3              5            3
# 4              6            3
# ..           ...          ...
# 515          594            4
# 516          595            1
# 517          596            6
# 518          597            2
# 519          599            1
#
# [520 rows x 2 columns]

# %% [markdown]
# # Create a Python function to get the number of rentals for each customer in June given the dataframe provided by the function rentals_june.

# %%
def customer_june(df):
    x = df.groupby("customer_id", as_index=False).agg('count')
    x['num_rentals']= x['rental_id']
    return x[['customer_id', 'num_rentals']]
df_june = customer_june(rentals_june(engine))
df_june
# Out:
#      customer_id  num_rentals
# 0              1            7
# 1              2            1
# 2              3            4
# 3              4            6
# 4              5            5
# ..           ...          ...
# 585          595            2
# 586          596            2
# 587          597            3
# 588          598            1
# 589          599            4
#
# [590 rows x 2 columns]

# %% [markdown]
# # Write a Python function named check_rentals that given:
#
# * a dataframe with the number of rentals in May by each customer_id
# * a dataframe with the number of rentals in June by each customer_id return a new dataframe with the following columns:
# * customer_id
# * Rentals_May
# * Rental_June
# * The difference between the previous columns

# %%
def check_rentals(x, y):
    merged = x.merge(y, on='customer_id', how='outer')
    merged.rename(columns={'num_rentals_x': 'Rentals_May',
                   'num_rentals_y': 'Rentals_June'}, inplace=True)
    merged['diff_may_june'] = merged['Rentals_June'] - merged['Rentals_May']
    return merged
check_rentals(df_may,df_june)
# Out:
#      customer_id  Rentals_May  Rentals_June  diff_may_june
# 0              1          2.0           7.0            5.0
# 1              2          1.0           1.0            0.0
# 2              3          2.0           4.0            2.0
# 3              5          3.0           5.0            2.0
# 4              6          3.0           4.0            1.0
# ..           ...          ...           ...            ...
# 593          583          NaN           6.0            NaN
# 594          585          NaN           4.0            NaN
# 595          591          NaN           3.0            NaN
# 596          592          NaN           5.0            NaN
# 597          598          NaN           1.0            NaN
#
# [598 rows x 4 columns]

# %% [markdown]
# # Create a Python function that given the dataframe returned by the previous function, returns another dataframe with the customer_id of customers who rented movies in may but didn't rent any movie in June.

# %%
def norent_june(df):
    norent = df[(~pd.isnull(df.Rentals_May)) & (pd.isnull(df.Rentals_June))].reset_index(drop=True)
    return norent
norent_june(check_rentals(df_may,df_june))
# Out:
#    customer_id  Rentals_May  Rentals_June  diff_may_june
# 0           61          1.0           NaN            NaN
# 1          101          1.0           NaN            NaN
# 2          332          2.0           NaN            NaN
# 3          401          3.0           NaN            NaN
# 4          433          2.0           NaN            NaN
# 5          440          1.0           NaN            NaN
# 6          445          2.0           NaN            NaN
# 7          475          2.0           NaN            NaN
